# %% [markdown]
# <a href="https://colab.research.google.com/github/Dream-Code/Dream-Code/blob/main/nn_img_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Steven Rivera
# # 01/03/2024
#
# # Simple Image Classification with MNIST Data

# %%
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.13.0

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.4927 - accuracy: 0.8259 - val_loss: 0.4276 - val_accuracy: 0.8461
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3741 - accuracy: 0.8652 - val_loss: 0.3790 - val_accuracy: 0.8644
# Epoch 3/10
# 1875/1875 [==============================] - 31s 17ms/step - loss: 0.3356 - accuracy: 0.8775 - val_loss: 0.3632 - val_accuracy: 0.8679
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3138 - accuracy: 0.8849 - val_loss: 0.3839 - val_accuracy: 0.8594
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2952 - accuracy: 0.8917 - val_loss: 0.3495 - val_accuracy: 0.8746
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2824 - accuracy: 0.8948 - val_loss: 0.3640 - val_accuracy: 0.8725
# Epoch 7/10
# ...

# %%
model.history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# # BEGIN MY_MODEL

# %% [markdown]
# Adding another hidden layer of size 32

# %%
# My model 2.0
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(32),
    tf.keras.layers.Dense(10)

])

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.4939 - accuracy: 0.8249 - val_loss: 0.4226 - val_accuracy: 0.8509
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3716 - accuracy: 0.8633 - val_loss: 0.3831 - val_accuracy: 0.8638
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3384 - accuracy: 0.8759 - val_loss: 0.3947 - val_accuracy: 0.8608
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3149 - accuracy: 0.8837 - val_loss: 0.3819 - val_accuracy: 0.8628
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2981 - accuracy: 0.8895 - val_loss: 0.3500 - val_accuracy: 0.8748
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2860 - accuracy: 0.8943 - val_loss: 0.3685 - val_accuracy: 0.8755
# Epoch 7/10
# ...

# %% [markdown]
# Adding the additional hidden layer did not improve on the original for the final result, though it did start with slightly lower loss and accuracy. At this point, I am going to go without adding the additional layer as I believe this is what the intent is (best model for each step)

# %% [markdown]
# ## Learning Rate

# %% [markdown]
# #### ETA = 0.01

# %%
# My model 2.0
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.01
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.5009 - accuracy: 0.8239 - val_loss: 0.4592 - val_accuracy: 0.8420
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3784 - accuracy: 0.8630 - val_loss: 0.4112 - val_accuracy: 0.8527
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3410 - accuracy: 0.8752 - val_loss: 0.3795 - val_accuracy: 0.8618
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3170 - accuracy: 0.8847 - val_loss: 0.3774 - val_accuracy: 0.8630
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2973 - accuracy: 0.8910 - val_loss: 0.3511 - val_accuracy: 0.8742
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2810 - accuracy: 0.8964 - val_loss: 0.3437 - val_accuracy: 0.8788
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# ### ETA = 0.001

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2200 - accuracy: 0.9170 - val_loss: 0.3505 - val_accuracy: 0.8816
# Epoch 2/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2134 - accuracy: 0.9207 - val_loss: 0.3345 - val_accuracy: 0.8893
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2055 - accuracy: 0.9228 - val_loss: 0.3581 - val_accuracy: 0.8825
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1988 - accuracy: 0.9252 - val_loss: 0.3576 - val_accuracy: 0.8796
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1934 - accuracy: 0.9275 - val_loss: 0.3510 - val_accuracy: 0.8849
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1902 - accuracy: 0.9274 - val_loss: 0.3626 - val_accuracy: 0.8897
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# ### ETA = 0.0001

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.0001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.1691 - accuracy: 0.9366 - val_loss: 0.3707 - val_accuracy: 0.8884
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1660 - accuracy: 0.9373 - val_loss: 0.3953 - val_accuracy: 0.8834
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1616 - accuracy: 0.9392 - val_loss: 0.3855 - val_accuracy: 0.8860
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1583 - accuracy: 0.9410 - val_loss: 0.3779 - val_accuracy: 0.8930
# Epoch 5/10
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.1548 - accuracy: 0.9416 - val_loss: 0.3768 - val_accuracy: 0.8911
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1516 - accuracy: 0.9428 - val_loss: 0.3814 - val_accuracy: 0.8877
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# ### ETA = 0.00001

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.00001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1364 - accuracy: 0.9488 - val_loss: 0.4207 - val_accuracy: 0.8896
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1329 - accuracy: 0.9503 - val_loss: 0.4098 - val_accuracy: 0.8887
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1305 - accuracy: 0.9512 - val_loss: 0.4440 - val_accuracy: 0.8811
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1280 - accuracy: 0.9515 - val_loss: 0.4170 - val_accuracy: 0.8893
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1246 - accuracy: 0.9536 - val_loss: 0.4220 - val_accuracy: 0.8911
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1242 - accuracy: 0.9532 - val_loss: 0.4249 - val_accuracy: 0.8910
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %%
plt.plot(my_model.history.history['loss'])
plt.plot(my_model.history.history['val_loss'])
plt.title('Train vs Test Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### ETA = 0.000001

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.000001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1127 - accuracy: 0.9582 - val_loss: 0.4776 - val_accuracy: 0.8900
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1140 - accuracy: 0.9578 - val_loss: 0.4786 - val_accuracy: 0.8847
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1095 - accuracy: 0.9592 - val_loss: 0.4762 - val_accuracy: 0.8892
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1079 - accuracy: 0.9597 - val_loss: 0.4893 - val_accuracy: 0.8865
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1052 - accuracy: 0.9604 - val_loss: 0.4952 - val_accuracy: 0.8863
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1040 - accuracy: 0.9601 - val_loss: 0.5075 - val_accuracy: 0.8892
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['loss'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accuracy', 'loss'], loc='upper left')
plt.show()

# %% [markdown]
# ### ETA = 0.0000001

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.0000001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0983 - accuracy: 0.9633 - val_loss: 0.5114 - val_accuracy: 0.8922
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0940 - accuracy: 0.9642 - val_loss: 0.5244 - val_accuracy: 0.8893
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0936 - accuracy: 0.9648 - val_loss: 0.5529 - val_accuracy: 0.8840
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0938 - accuracy: 0.9644 - val_loss: 0.5271 - val_accuracy: 0.8862
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0908 - accuracy: 0.9659 - val_loss: 0.5477 - val_accuracy: 0.8897
# Epoch 6/10
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0893 - accuracy: 0.9663 - val_loss: 0.5763 - val_accuracy: 0.8841
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# #### Trying ETA = 0.1 since as the learning rate gets smaller, the divide between accuracy and loss grows

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.1
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.0853 - accuracy: 0.9681 - val_loss: 0.5984 - val_accuracy: 0.8890
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0805 - accuracy: 0.9698 - val_loss: 0.5835 - val_accuracy: 0.8857
# Epoch 3/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0830 - accuracy: 0.9692 - val_loss: 0.5833 - val_accuracy: 0.8893
# Epoch 4/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0806 - accuracy: 0.9703 - val_loss: 0.5753 - val_accuracy: 0.8834
# Epoch 5/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0781 - accuracy: 0.9713 - val_loss: 0.5900 - val_accuracy: 0.8902
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0763 - accuracy: 0.9709 - val_loss: 0.6022 - val_accuracy: 0.8893
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# There is a clear improvement in accuracy and loss as the step rate decreases (or increases from the default) (smaller steps at each iteration), however for the final two tests the accuracy and loss improve very slightly at the cost of much longer run times. Additionally, there is a wide gap between the train and test set accuracy where we find the accuracy for the test set really doesn't improve at all and only minimal improvements in the training set
#
# After ETA = 0.0001 the improvement in accuracy over 10 iterations is less than 1%, while not insignificant, should be considered with the computational cost., For the remainder of the hyperparameters I will be using the ETA 0.00001 with an accuracy value of 95.74%

# %% [markdown]
# ## Regularization Methods

# %% [markdown]
# ### L1

# %% [markdown]
# #### L1 = 1e-5

# %%
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L1(l1=1e-5)),
    tf.keras.layers.Dense(10)
])

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.00001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0768 - accuracy: 0.9708 - val_loss: 0.6521 - val_accuracy: 0.8844
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0706 - accuracy: 0.9730 - val_loss: 0.6325 - val_accuracy: 0.8865
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0741 - accuracy: 0.9726 - val_loss: 0.6492 - val_accuracy: 0.8914
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0706 - accuracy: 0.9738 - val_loss: 0.6270 - val_accuracy: 0.8890
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0730 - accuracy: 0.9724 - val_loss: 0.6387 - val_accuracy: 0.8899
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0683 - accuracy: 0.9743 - val_loss: 0.6496 - val_accuracy: 0.8903
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# ### L1 = 1e-2

# %%
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L1(l1=1e-2)),
    tf.keras.layers.Dense(10)
])

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.00001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 2.2513 - accuracy: 0.7103 - val_loss: 1.3303 - val_accuracy: 0.7337
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 1.2192 - accuracy: 0.7558 - val_loss: 1.1997 - val_accuracy: 0.7537
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 1.1506 - accuracy: 0.7628 - val_loss: 1.1386 - val_accuracy: 0.7608
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 1.1082 - accuracy: 0.7707 - val_loss: 1.1750 - val_accuracy: 0.7503
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 1.0881 - accuracy: 0.7734 - val_loss: 1.0935 - val_accuracy: 0.7653
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 1.0666 - accuracy: 0.7765 - val_loss: 1.0735 - val_accuracy: 0.7788
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# Finally some hint of an improvement, with the caveat that the accuracy for both test and train sets are significantly lower than previous runs

# %% [markdown]
# ### L1 = 1e-7

# %%
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L1(l1=1e-7)),
    tf.keras.layers.Dense(10)
])

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.00001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.5023 - accuracy: 0.8225 - val_loss: 0.4167 - val_accuracy: 0.8512
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3767 - accuracy: 0.8642 - val_loss: 0.4057 - val_accuracy: 0.8540
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3378 - accuracy: 0.8761 - val_loss: 0.3778 - val_accuracy: 0.8631
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3146 - accuracy: 0.8856 - val_loss: 0.3783 - val_accuracy: 0.8606
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2969 - accuracy: 0.8898 - val_loss: 0.3375 - val_accuracy: 0.8781
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2835 - accuracy: 0.8940 - val_loss: 0.3433 - val_accuracy: 0.8760
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# Here is also a little better and also very slightly improved from the base model's accuracy

# %% [markdown]
# ### L2

# %% [markdown]
# #### L2 = 1e-5

# %%
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(l2=1e-5)),
    tf.keras.layers.Dense(10)
])

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.00001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2331 - accuracy: 0.9125 - val_loss: 0.3321 - val_accuracy: 0.8881
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2247 - accuracy: 0.9161 - val_loss: 0.3261 - val_accuracy: 0.8882
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2185 - accuracy: 0.9188 - val_loss: 0.3342 - val_accuracy: 0.8870
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2111 - accuracy: 0.9205 - val_loss: 0.3540 - val_accuracy: 0.8833
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2057 - accuracy: 0.9229 - val_loss: 0.3437 - val_accuracy: 0.8879
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2020 - accuracy: 0.9250 - val_loss: 0.3582 - val_accuracy: 0.8866
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# #### L2 = 1e-2

# %%
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(l2=1e-2)),
    tf.keras.layers.Dense(10)
])

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.00001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.8559 - accuracy: 0.7955 - val_loss: 0.7517 - val_accuracy: 0.7817
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6488 - accuracy: 0.8117 - val_loss: 0.6664 - val_accuracy: 0.8073
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.6245 - accuracy: 0.8180 - val_loss: 0.6532 - val_accuracy: 0.8073
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.5971 - accuracy: 0.8260 - val_loss: 0.5853 - val_accuracy: 0.8312
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5892 - accuracy: 0.8278 - val_loss: 0.6512 - val_accuracy: 0.8057
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5773 - accuracy: 0.8313 - val_loss: 0.5636 - val_accuracy: 0.8400
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# #### L2 = 1e-7

# %%
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(l2=1e-7)),
    tf.keras.layers.Dense(10)
])

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.00001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5019 - accuracy: 0.8248 - val_loss: 0.4438 - val_accuracy: 0.8433
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3776 - accuracy: 0.8634 - val_loss: 0.3890 - val_accuracy: 0.8585
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3380 - accuracy: 0.8773 - val_loss: 0.3759 - val_accuracy: 0.8609
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3126 - accuracy: 0.8862 - val_loss: 0.3653 - val_accuracy: 0.8698
# Epoch 5/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2956 - accuracy: 0.8921 - val_loss: 0.3460 - val_accuracy: 0.8770
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2816 - accuracy: 0.8960 - val_loss: 0.3505 - val_accuracy: 0.8710
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# L2 = 1e-7 does give better accuracy than the previous regularization methods/tweaks however there is a decrease in overall accuracy of 4.51% and it might be better to just leave it as is since there is no discernable improvement in the loss function and runtime is longer. Going further where L2 = 1e-9 doesnt make much sense, even 1e-7 seems negligible to me without real benefit
#
# I will proceed with my model with it included

# %% [markdown]
# ## Dropout

# %% [markdown]
# #### Dropout = 0.5

# %%
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(l2=1e-7)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10)
])

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.00001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.6246 - accuracy: 0.7797 - val_loss: 0.4478 - val_accuracy: 0.8398
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4718 - accuracy: 0.8299 - val_loss: 0.4209 - val_accuracy: 0.8454
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4439 - accuracy: 0.8392 - val_loss: 0.4017 - val_accuracy: 0.8564
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4212 - accuracy: 0.8479 - val_loss: 0.3912 - val_accuracy: 0.8611
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4077 - accuracy: 0.8515 - val_loss: 0.3904 - val_accuracy: 0.8584
# Epoch 6/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.3969 - accuracy: 0.8561 - val_loss: 0.3804 - val_accuracy: 0.8619
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# #### Dropout = 0.2

# %%
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(l2=1e-7)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10)
])

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.00001
)

my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.5287 - accuracy: 0.8116 - val_loss: 0.4411 - val_accuracy: 0.8414
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3996 - accuracy: 0.8557 - val_loss: 0.3889 - val_accuracy: 0.8635
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3656 - accuracy: 0.8670 - val_loss: 0.3735 - val_accuracy: 0.8640
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3427 - accuracy: 0.8744 - val_loss: 0.3794 - val_accuracy: 0.8648
# Epoch 5/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.3307 - accuracy: 0.8776 - val_loss: 0.3632 - val_accuracy: 0.8709
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3189 - accuracy: 0.8832 - val_loss: 0.3546 - val_accuracy: 0.8731
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# #### Dropout = 0.3

# %%
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(l2=1e-7)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(10)
])

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.00001
)

my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.5514 - accuracy: 0.8041 - val_loss: 0.4349 - val_accuracy: 0.8428
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4149 - accuracy: 0.8501 - val_loss: 0.3945 - val_accuracy: 0.8610
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3853 - accuracy: 0.8596 - val_loss: 0.3761 - val_accuracy: 0.8648
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3637 - accuracy: 0.8677 - val_loss: 0.3628 - val_accuracy: 0.8662
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3503 - accuracy: 0.8736 - val_loss: 0.3602 - val_accuracy: 0.8701
# Epoch 6/10
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.3367 - accuracy: 0.8758 - val_loss: 0.3535 - val_accuracy: 0.8702
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# #### Dropout = 0.2, no regularization

# %%
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10)
])

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.000001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.5360 - accuracy: 0.8092 - val_loss: 0.4342 - val_accuracy: 0.8444
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3990 - accuracy: 0.8555 - val_loss: 0.3846 - val_accuracy: 0.8616
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3649 - accuracy: 0.8662 - val_loss: 0.3909 - val_accuracy: 0.8487
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3420 - accuracy: 0.8750 - val_loss: 0.3751 - val_accuracy: 0.8635
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3290 - accuracy: 0.8789 - val_loss: 0.3596 - val_accuracy: 0.8688
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3138 - accuracy: 0.8829 - val_loss: 0.3627 - val_accuracy: 0.8670
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# There really has been no improvement in accuracy since the learning rate, however the train/test accuracy divide has improved significantly with dropout and regularization, which may be a valid trade off for a valid model that learns.

# %% [markdown]
# ## Best model
#
# The best model removes the additional hidden layer of 32 nodes, a dropout value of 0.3, a learning rate of 0.00001 and regularization using L2 = 1e-7. As noted above, this does have a smaller training set accuracy, however the test set accuracy is much higher and more in line with the training accuracy meaning more valid results.

# %%
my_model= tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(l2=1e-7)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(10)
])

# %%
tf.keras.optimizers.experimental.Adam(
    learning_rate=0.00001
)

# %%
my_model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
my_model.fit(train_images, train_labels, epochs=10, validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.5525 - accuracy: 0.8059 - val_loss: 0.4496 - val_accuracy: 0.8392
# Epoch 2/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.4195 - accuracy: 0.8485 - val_loss: 0.3988 - val_accuracy: 0.8558
# Epoch 3/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3850 - accuracy: 0.8592 - val_loss: 0.3882 - val_accuracy: 0.8597
# Epoch 4/10
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.3653 - accuracy: 0.8651 - val_loss: 0.3742 - val_accuracy: 0.8614
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3502 - accuracy: 0.8722 - val_loss: 0.3587 - val_accuracy: 0.8718
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3383 - accuracy: 0.8747 - val_loss: 0.3558 - val_accuracy: 0.8685
# Epoch 7/10
# ...

# %%
plt.plot(my_model.history.history['accuracy'])
plt.plot(my_model.history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# ## END MY_MODEL
